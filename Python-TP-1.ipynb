# %% [markdown]
# # Practical_1: Variables and Assignments

# %% [markdown]
# ----
#
# ### Exercise 1:
# Declare a variable `x` and assign it the value `10`.
#
# ```python
# # Exercise 1
# ```
#
# ---
#
# ### Exercise 2:
# Assign the value `True` to a variable called `is_valid`.
#
# ```python
# # Exercise 2
# ```
#
# ---
#
# ### Exercise 3:
# Create a string variable `name` with the value "Python Programming".
#
# ```python
# # Exercise 3
# ```
#
# ---
#
# ### Exercise 4:
# Assign the result of `5 + 3` to a variable `sum_result`.
#
# ```python
# # Exercise 4
# ```
#
# ---
#
# ### Exercise 5:
# Assign multiple variables in one line: `a = 5`, `b = 10`, `c = 15`.
#
# ```python
# # Exercise 5
# ```
#
# ---
#
# ### Exercise 6:
# Assign the value of one variable `x` to another variable `y`.
#
# ```python
# # Exercise 6
# ```
#
# ---
#
# ### Exercise 7:
# Assign a floating-point number `9.8` to a variable `gravity`.
#
# ```python
# # Exercise 7
# ```
#
# ---
#
# ### Exercise 8:
# Create a variable `country` and assign it the string value of your favorite country.
#
# ```python
# # Exercise 8
# ```
#
# ---
#
# ### Exercise 9:
# Change the value of variable `age` from `25` to `26` in two separate steps.
#
# ```python
# # Exercise 9
# ```
#
# ---
#
# ### Exercise 10:
# Use one variable to store the result of subtracting two numbers `20 - 7`.
#
# ```python
# # Exercise 10
# ```
#
# ---
#
# ### Exercise 11:
# Assign an integer value and a floating-point value to two different variables.
#
# ```python
# # Exercise 11
# ```
#
# ---
#
# ### Exercise 12:
# Assign a boolean value `False` to a variable `is_completed`.
#
# ```python
# # Exercise 12
# ```
#
# ---
#
# ### Exercise 13:
# Swap the values of two variables `x` and `y`.
#
# ```python
# # Exercise 13
# ```
#
# ---
#
# ### Exercise 14:
# Assign a complex number `3 + 4j` to a variable `complex_num`.
#
# ```python
# # Exercise 14
# ```
#
# ---
#
# ### Exercise 15:
# Reassign a variable from an integer to a string.
#
# ```python
# # Exercise 15
# ```
#
# ---
#
# ### Exercise 16:
# Create two variables `first_name` and `last_name`, and assign them your first and last names.
#
# ```python
# # Exercise 16
# ```
#
# ---
#
# ### Exercise 17:
# Create a variable `temperature` and assign it the value of `35.5`.
#
# ```python
# # Exercise 17
# ```
#
# ---
#
# ### Exercise 18:
# Assign the result of the multiplication of two numbers `8 * 6` to a variable `product`.
#
# ```python
# # Exercise 18
# ```
#
# ---
#
# ### Exercise 19:
# Assign a sentence of your choice to a variable `sentence`.
#
# ```python
# # Exercise 19
# ```
#
# ---
#
# ### Exercise 20:
# Use an assignment to convert a string `'50'` into an integer variable `int_value`.
#
# ```python
# # Exercise 20
# ```
#
# ---
#
# ### Exercise 21:
# Assign the result of dividing `144` by `12` to a variable `quotient`.
#
# ```python
# # Exercise 21
# ```
#
# ---
#
# ### Exercise 22:
# Assign the remainder of `47 divided by 5` to a variable `remainder`.
#
# ```python
# # Exercise 22
# ```
#
# ---
#
# ### Exercise 23:
# Create a variable `is_student` and assign it the value `True`.
#
# ```python
# # Exercise 23
# ```
#
# ---
#
# ### Exercise 24:
# Use a variable to store the result of a modulo operation: `45 % 4`.
#
# ```python
# # Exercise 24
# ```
#
# ---
#
# ### Exercise 25:
# Create a variable `pi` and assign it the value `3.14159`.
#
# ```python
# # Exercise 25
# ```
#
# ---
#
# ### Exercise 26:
# Create two variables `length` and `width`, assign them values, and calculate the area of a rectangle.
#
# ```python
# # Exercise 26
# ```
#
# ---
#
# ### Exercise 27:
# Assign a negative number to a variable `negative_value`.
#
# ```python
# # Exercise 27
# ```
#
# ---
#
# ### Exercise 28:
# Assign a string containing a special character (e.g., "Hello, World!") to a variable `greeting`.
#
# ```python
# # Exercise 28
# ```
#
# ---
#
# ### Exercise 29:
# Create a variable `population` and assign it a large integer value (in billions).
#
# ```python
# # Exercise 29
# ```
#
# ---
#
# ### Exercise 30:
# Use a variable to store the result of raising `2` to the power of `8`.
#
# ```python
# # Exercise 30
# ```
#
# ---
#
# ### Exercise 31:
# Assign a list of your favorite fruits to a variable `fruits`.
#
# ```python
# # Exercise 31
# ```
#
# ---
#
# ### Exercise 32:
# Assign a tuple of three numbers to a variable `coordinates`.
#
# ```python
# # Exercise 32
# ```
#
# ---
#
# ### Exercise 33:
# Assign a dictionary with keys `name` and `age` to a variable `person`.
#
# ```python
# # Exercise 33
# ```
#
# ---
#
# ### Exercise 34:
# Use variables to store the sum of two floating-point numbers.
#
# ```python
# # Exercise 34
# ```
#
# ---
#
# ### Exercise 35:
# Create a variable `is_sunny` and assign it the result of a comparison `10 > 5`.
#
# ```python
# # Exercise 35
# ```
#
# ---
#
# ### Exercise 36:
# Assign a string and an integer to two different variables, then print both on one line.
#
# ```python
# # Exercise 36
# ```
#
# ---
#
# ### Exercise 37:
# Reassign a variable that originally held a number to a boolean value.
#
# ```python
# # Exercise 37
# ```
#
# ---
#
# ### Exercise 38:
# Create a variable `is_weekend` and assign it the result of `False`.
#
# ```python
# # Exercise 38
# ```
#
# ---
#
# ### Exercise 39:
# Assign a multi-line string to a variable `description`.
#
# ```python
# # Exercise 39
# ```
#
# ---
#
# ### Exercise 40:
# Use variables to store the result of the absolute value of `-25`.
#
# ```python
# # Exercise 40
# ```
#
# ---
#
# ### Exercise 41:
# Assign the result of a floor division `100 // 6` to a variable `floor_div_result`.
#
# ```python
# # Exercise 41
# ```
#
# ---
#
# ### Exercise 42:
# Assign the result of adding a floating-point number to an integer to a variable `mixed_sum`.
#
# ```python
# # Exercise 42
# ```
#
# ---
#
#
# ### Exercise 43:
# Assign a boolean value based on the comparison of two variables `a = 10` and `b = 15`.
#
# ```python
# # Exercise 43
# ```
#
# ---
#
# ### Exercise 44:
# Assign a long sentence to a variable and count its characters using `len()`.
#
# ```python
# # Exercise 44
# ```
#
# ---
#
# ### Exercise 45:
# Assign a fractional result `7 / 3` to a variable `division_result`.
#
# ```python
# # Exercise 45
# ```
#
# ---
#
# ### Exercise 46:
# Create a variable `speed` and assign it the value of 100 kilometers per hour.
#
# ```python
# # Exercise 46
# ```
#
# ---
#
# ### Exercise 47:
# Assign a multi-variable equation like `y = 3x + 5` where `x = 4` to a variable `y`.
#
# ```python
# # Exercise 47
# ```
#
# ---
#
# ### Exercise 48:
# Use variables to calculate and store the average of three numbers.
#
# ```python
# # Exercise 48
# ```
#
# ****

# %%
#Exercise 1

x= 10

# Exercise 2

is_valid = True

# Exercise 3

name = 'Python Programming'

#  Exercise 4

sum_result = 5 + 3

#  Exercise 5

a = 5 ; b = 10 ; c = 15
x,y,z = 5,10,15

print(a,b,c)
print(x,y,z)
#Exercise 6

y = x
 

#Exercise 7

gravity = 9.8

#Exercise 8

country = "Cameroon"

#Exercise 9

age = 25
age = age + 1 #26 now


#Exercise 10

result_subtract = 20 - 7

#Exercise 11

my_var_int =  22
my_var_float =  22.34

#Exercise 12

is_completed = False

#Exercise 13

tmp= y
y = x
y = tmp

x = x + y
y = x- y 

#Exercise 14

complex_num  = 2 + 4j

#Exercise 15

my_var_int =3
my_var_int =  'Rosly'

#Exercise 16

first_name = 'Rosly'
last_name = 'Mamekem'

#Exercise 17

temperature = 35.5

#Exercise 18

product =  8 * 6

#Exercise 19

sentence = ' What matter is solving problem'

#Exercise 20

int_value = int('50')

#Exercise 21

quotient = 144 / 12

#Exercise 22

remainder =  47 % 5

#Exercise 23

is_student =  True

#Exercise 24

pi = 3.14159

#Exercise 25

length = 3
width = 24

area_rectangle = length * width

#Exercise 27

negative_value = -1

#Exercise 28

greeting = 'Hello  Rosly ! how are you today ? '

#Exercise 29


population = 2 ** 2048 #RSA security parameter 
print(population)


#Exercise 30

my_power = 2 ** 8

#Exercise 31

my_fruits = ['Orange', 'Banana']

#Exercise 32

coordinates = (3,2,4)

#Exercise 33

person = { name : 'Rosly MAMEKEM', 
            age: 43
        }

#Exercise 34

is_sunny = (10 > 5)

#Exercise 35

my_string = 'str string'
my_var_int = 24

print(my_string, my_var_int)

#Exercise 37

num_value = 10
num_value = True
print(num_value, type(num_value))
#Exercise 38

is_weekend = False

#Exercise 39 

description = """dada
vxxvxvvx dsd sd s d nxnbnxc 
 sjksjkk  sdjskd sdalb dh s hsdkb jsbkbdsb jsbjjdb sjdldalndcbadbhb s d shbkdbdwbobd bhdbnbjkb 
cnsbndbn
dda """

#Exercise 40

my_absolute = abs(-25)

print(my_absolute)

#Exercise 41

floor_div_result = 100 //6 

#Exercise 42

a= 234
b=2
my_boolean =  True if a == b else  False 


print(my_boolean)

#Exercise 43

phrase = 'nd ald  adl adln  ghgggh'
print(len(phrase))

#Exercise 45

division_result = 7 / 3 

#Exercise 46

speed = '100km/h'

#Exercise 47

x= 4
y = 3* x +5
print(y)

#Exercise 48

average =(23 + 11 + 93) / 3

#Exercise 49
# Out:
# 5 10 15
# 5 10 15
# ...
# str string 24
# True <class 'bool'>
# 25
# False
# 24
# 17

# %%
x=  5
y= 3

x = x + y
y = x - y
x = x -y

print(x,y)

complex_num  = 2 + 4j
type(complex_num)

int_value = str(7)
a = True
type(a)
print( bool(10) )

print()
# Out:
# 3 5
# True
